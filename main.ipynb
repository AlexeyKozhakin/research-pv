# %%
import pandas as pd
data = pd.read_csv('payment_data.csv')

# %%
data.columns
# Out:
# Index(['user_id', 'date', 'sum_of_deposit', 'sum_of_withdraw'], dtype='object')

# %%
data.shape
# Out:
# (290846, 4)

# %%
data[((data['sum_of_deposit']!=0) &
      (data['sum_of_withdraw']!=0))]
# Out:
#         user_id        date  sum_of_deposit  sum_of_withdraw
# 16            1  2024-01-19          120.38           157.53
# 17            1  2024-01-20           50.13           225.10
# 23            1  2024-01-29          101.38           548.06
# 31            1  2024-02-09           40.76           404.81
# 39            1  2024-02-18           62.88           311.77
# ...         ...         ...             ...              ...
# 290830     1000  2024-12-14          194.17           185.39
# 290832     1000  2024-12-16          774.09            96.14
# 290834     1000  2024-12-18          335.85           158.07
# 290844     1000  2024-12-29          150.07           111.50
# 290845     1000  2024-12-30          139.33           115.96
#
# [55110 rows x 4 columns]

# %%
# !pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.9.0
# argon2-cffi               23.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.4
# bleach                    6.2.0
# certifi                   2025.1.31
# cffi                      1.17.1
# charset-normalizer        3.4.1
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.3.2
# cycler                    0.12.1
# debugpy                   1.8.14
# decorator                 5.2.1
# defusedxml                0.7.1
# exceptiongroup            1.2.2
# executing                 2.2.0
# fastjsonschema            2.21.1
# fonttools                 4.57.0
# fqdn                      1.5.1
# h11                       0.14.0
# ...
